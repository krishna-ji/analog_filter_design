# %%
# NORMALIZED BUTTERWORTH FILTER
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import zpk2tf, bode, TransferFunction, buttap

# filter specification
order = 4
# cutoff_freq_hz = 5  # Cutoff frequency in Hz
# cutoff_freq_rad = 2 * np.pi * cutoff_freq_hz  # Convert to rad/s

z, p, k = buttap(4)  # 4th order Butterworth filter
num, denom = zpk2tf(z, p, k) # get tf
# num, denom = lp2lp(num, denom, cutoff_freq_rad) # DENORMALIZED TO CUTOFF FREQ FOR TRANSFER FUNCTION


filterTF = TransferFunction(num,denom)
print(filterTF)

# frequency vector
w_log = np.logspace(-1,2,1000) # from 10e-1 to 10e3, with 1000 points

# Compute the Bode plot
w_log, mag, phase = bode(filterTF, w=w_log)
# mag = 10**(mag/20) # mag in linear scale


# Plot the Bode magnitude and phase
plt.figure(figsize=(12, 8))

# Magnitude plot
plt.subplot(2, 1, 1) # 2 rows, 1 column, 1st subplot
plt.semilogx(w_log, mag)  # Bode magnitude plot (logarithmic x-axis)
plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Magnitude [dB]')
plt.title('Bode Plot - Magnitude Response')

# Phase plot
plt.subplot(2, 1, 2) # 2 rows, 1 column, 2nd subplot
plt.semilogx(w_log, phase)  # Bode phase plot (logarithmic x-axis)
plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Phase [degrees]')
plt.title('Bode Plot - Phase Response')

# Show plots
plt.tight_layout()
plt.show()
# Out:
# TransferFunctionContinuous(
# array([1.]),
# array([1.        , 2.61312593, 3.41421356, 2.61312593, 1.        ]),
# dt: None
# )

# %%
#  NORMALIZED CHEBYSHEV TYPE I FILTER
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import cheb1ap, zpk2tf, bode, TransferFunction, lp2lp

# Filter specification
order = 4
rp = 1  # Passband ripple in dB
# cutoff_freq_hz = 5  # Cutoff frequency in Hz
# cutoff_freq_rad = 2 * np.pi * cutoff_freq_hz  # Convert to rad/s

# Get normalized Chebyshev Type I filter (cutoff at 1 rad/s)
z, p, k = cheb1ap(order, rp)

# Scale the filter to the desired cutoff frequency
num, denom = zpk2tf(z, p, k)
# num, denom = lp2lp(num, denom, cutoff_freq_rad)


filterTF = TransferFunction(num, denom)
print(filterTF)

# Frequency vector for Bode plot
w_log = np.logspace(-1, 2, 1000)  # from 10^-1 to 10^2 rad/s, with 1000 points

# Compute the Bode plot
w_log, mag, phase = bode(filterTF, w=w_log)
# mag = 10**(mag/20)  # mag in linear scale

# Plot the Bode magnitude and phase
plt.figure(figsize=(12, 8))

# Magnitude plot
plt.subplot(2, 1, 1)  # 2 rows, 1 column, 1st subplot
plt.semilogx(w_log, mag)  # Bode magnitude plot (logarithmic x-axis)
plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Magnitude [dB]')
plt.title('Bode Plot - Magnitude Response')

# Phase plot
plt.subplot(2, 1, 2)  # 2 rows, 1 column, 2nd subplot
plt.semilogx(w_log, phase)  # Bode phase plot (logarithmic x-axis)
plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Phase [degrees]')
plt.title('Bode Plot - Phase Response')

# Show plots
plt.tight_layout()
plt.show()
# Out:
# TransferFunctionContinuous(
# array([0.24565334]),
# array([1.        , 0.95281138, 1.45392476, 0.74261937, 0.27562758]),
# dt: None
# )

# %%
# BESSEL FILTER NORMALIZED
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import besselap, zpk2tf, bode, TransferFunction, lp2lp

# Filter specification
order = 4
# cutoff_freq_hz = 5  # Cutoff frequency in Hz
# cutoff_freq_rad = 2 * np.pi * cutoff_freq_hz  # Convert to rad/s

# Get normalized Bessel filter (cutoff at 1 rad/s)
z, p, k = besselap(order)

# Scale the filter to the desired cutoff frequency
num, denom = zpk2tf(z, p, k)
# num, denom = lp2lp(num, denom, cutoff_freq_rad)

filterTF = TransferFunction(num, denom)
print(filterTF)

# Frequency vector for Bode plot
w_log = np.logspace(-1, 2, 1000)  # from 10^-1 to 10^2 rad/s, with 1000 points

# Compute the Bode plot
w_log, mag, phase = bode(filterTF, w=w_log)
# mag = 10**(mag/20)  # mag in linear scale

# Plot the Bode magnitude and phase
plt.figure(figsize=(12, 8))

# Magnitude plot
plt.subplot(2, 1, 1)  # 2 rows, 1 column, 1st subplot
plt.semilogx(w_log, mag)  # Bode magnitude plot (logarithmic x-axis)
plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Magnitude [dB]')
plt.title('Bode Plot - Magnitude Response')

# Phase plot
plt.subplot(2, 1, 2)  # 2 rows, 1 column, 2nd subplot
plt.semilogx(w_log, phase)  # Bode phase plot (logarithmic x-axis)
plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Phase [degrees]')
plt.title('Bode Plot - Phase Response')

# Show plots
plt.tight_layout()
plt.show()
# Out:
# TransferFunctionContinuous(
# array([1.]),
# array([1.        , 3.12393994, 4.39155033, 3.20108587, 1.        ]),
# dt: None
# )

# %%
# ELLIPTIC FILTER NORMALIZED
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import ellipap, zpk2tf, bode, TransferFunction, lp2lp

# Filter specification
order = 4
# cutoff_freq_hz = 5  # Cutoff frequency in Hz
# cutoff_freq_rad = 2 * np.pi * cutoff_freq_hz  # Convert to rad/s
rp = 1  # Passband ripple in dB
rs = 40  # Stopband attenuation in dB

# Get normalized Elliptic filter (cutoff at 1 rad/s)
z, p, k = ellipap(order, rp, rs)

# Scale the filter to the desired cutoff frequency
num, denom = zpk2tf(z, p, k)
# num, denom = lp2lp(num, denom, cutoff_freq_rad)

filterTF = TransferFunction(num, denom)
print(filterTF)

# Frequency vector for Bode plot
w_log = np.logspace(-1, 2, 1000)  # from 10^-1 to 10^2 rad/s, with 1000 points

# Compute the Bode plot
w_log, mag, phase = bode(filterTF, w=w_log)
# mag = 10**(mag/20)  # mag in linear scale

# Plot the Bode magnitude and phase
plt.figure(figsize=(12, 8))

# Magnitude plot
plt.subplot(2, 1, 1)  # 2 rows, 1 column, 1st subplot
plt.semilogx(w_log, mag)  # Bode magnitude plot (logarithmic x-axis)
plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Magnitude [dB]')
plt.title('Bode Plot - Magnitude Response')

# Phase plot
plt.subplot(2, 1, 2)  # 2 rows, 1 column, 2nd subplot
plt.semilogx(w_log, phase)  # Bode phase plot (logarithmic x-axis)
plt.grid(True, which='both', linestyle='--', linewidth=0.7)
plt.xlabel('Frequency [rad/s]')
plt.ylabel('Phase [degrees]')
plt.title('Bode Plot - Phase Response')

# Show plots
plt.tight_layout()
plt.show()
# Out:
# TransferFunctionContinuous(
# array([0.01      , 0.        , 0.15018304, 0.        , 0.32195726]),
# array([1.        , 0.93914372, 1.51372547, 0.80369618, 0.36124199]),
# dt: None
# )
